# %%
import numpy as np
import pandas as pd
df_1 = pd.read_csv("Accident_Cities.csv")
#df_2 = pd.read_csv("Accident_States.csv")
print(df_1)
#print(df_2)
# Out:
#         Name of City  Total number of Fatal Accidents - 2011  \
# 0               Agra                                   336.0
# 1          Ahmedabad                                   222.0
# 2   Asansol-Durgapur                                   229.0
# 3         Aurangabad                                   161.0
# 4          Bengaluru                                   689.0
# 5             Bhopal                                   275.0
# 6         Coimbatore                                   253.0
# 7              Delhi                                  2007.0
# 8            Dhanbad                                    74.0
# 9          Faridabad                                   229.0
# 10         Ghaziabad                                   495.0
# 11           Gwalior                                   233.0
# 12         Hyderabad                                   428.0
# 13            Indore                                   407.0
# ...

# %%
df_1.head()
# Out:
#        Name of City  Total number of Fatal Accidents - 2011  \
# 0              Agra                                   336.0
# 1         Ahmedabad                                   222.0
# 2  Asansol-Durgapur                                   229.0
# 3        Aurangabad                                   161.0
# 4         Bengaluru                                   689.0
#
#    All Accidents - 2011  Persons Killed - 2011  Persons Injured - 2011  \
# 0                1299.0                  632.0                  1046.0
# 1                2020.0                  227.0                  2036.0
# 2                 368.0                  230.0                   185.0
# 3                 719.0                  173.0                   744.0
# 4                6031.0                  720.0                  4952.0
#
#    Total number of Fatal Accidents - 2012  All Accidents - 2012  \
# 0                                   381.0                 922.0
# ...

# %%
df_1['Name of City']
# Out:
# 0                 Agra
# 1            Ahmedabad
# 2     Asansol-Durgapur
# 3           Aurangabad
# 4            Bengaluru
# 5               Bhopal
# 6           Coimbatore
# 7                Delhi
# 8              Dhanbad
# 9            Faridabad
# 10           Ghaziabad
# 11             Gwalior
# 12           Hyderabad
# 13              Indore
# 14              Jaipur
# 15            Jabalpur
# 16          Jamshedpur
# 17             Jodhpur
# 18               Kochi
# 19             Kolkata
# 20              Kollam
# 21                Kota
# 22              Kannur
# 23             Lucknow
# 24            Ludhiana
# 25             Madurai
# 26          Mallapuram
# 27              Mumbai
# 28              Meerut
# 29              Nagpur
# 30               Patna
# 31                Pune
# 32              Rajkot
# 33               Surat
# 34            Srinagar
# 35            Thrissur
# 36             Vadodra
# 37            Varanasi
# 38       Visakhapatnam
# 39           Allahabad
# ...

# %%
print(df_1[['Persons Injured-2011','Persons Injured-2012','Persons Injured-2013','Persons Injured-2014','Persons Injured-2015']].max())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-2911abecdbcf> in <module>()
# ----> 1 print(df_1[['Persons Injured-2011','Persons Injured-2012','Persons Injured-2013','Persons Injured-2014','Persons Injured-2015']].max())
#
# /home/sois/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2054         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2055             # either boolean or fancy integer index
# -> 2056             return self._getitem_array(key)
#    2057         elif isinstance(key, DataFrame):
#    2058             return self._getitem_frame(key)
#
# /home/sois/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2098             return self.take(indexer, axis=0, convert=False)
#    2099         else:
# ...

# %%
df_1.loc[1:2,::4].max()
# Out:
# Name of City              Asansol-Durgapur
# Persons Injured - 2011                2036
# Persons Injured - 2012                1845
# Injured - 2013                        1855
# Minor Accidents - 2014                1123
# Injured - 2014                        1597
# Minor Accidents - 2015                1168
# Injured - 2015                        1722
# dtype: object

# %%
df_1
# Out:
#         Name of City  Total number of Fatal Accidents - 2011  \
# 0               Agra                                   336.0
# 1          Ahmedabad                                   222.0
# 2   Asansol-Durgapur                                   229.0
# 3         Aurangabad                                   161.0
# 4          Bengaluru                                   689.0
# 5             Bhopal                                   275.0
# 6         Coimbatore                                   253.0
# 7              Delhi                                  2007.0
# 8            Dhanbad                                    74.0
# 9          Faridabad                                   229.0
# 10         Ghaziabad                                   495.0
# 11           Gwalior                                   233.0
# 12         Hyderabad                                   428.0
# 13            Indore                                   407.0
# ...

# %%
df_1['Name of City'] = df_1[[                ]].max()

# %%
df_3
# Out:
# Persons Injured - 2011    7226.0
# Persons Injured - 2012    8628.0
# Injured - 2013            8700.0
# Injured - 2014            9355.0
# Injured - 2015            8258.0
# dtype: float64

# %%
df_1 = pd.DataFrame(df_1,columns=['Name of City','Persons Injured - 2011','Persons Injured - 2012','Injured - 2013','Injured - 2014','Injured - 2015'])
df_1
# Out:
#     Name of City  Persons Injured - 2011  Persons Injured - 2012  \
# 0            NaN                  1046.0                   675.0
# 1            NaN                  2036.0                  1845.0
# 2            NaN                   185.0                   315.0
# 3            NaN                   744.0                   649.0
# 4            NaN                  4952.0                  4527.0
# 5            NaN                  2970.0                  3076.0
# 6            NaN                  1058.0                  1004.0
# 7            NaN                  7226.0                  6633.0
# 8            NaN                   106.0                   191.0
# 9            NaN                   595.0                   537.0
# 10           NaN                   817.0                   710.0
# 11           NaN                  1626.0                  1434.0
# 12           NaN                  2528.0                  2471.0
# ...

# %%
df_1['Name of City']
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# 36   NaN
# 37   NaN
# 38   NaN
# 39   NaN
# 40   NaN
# 41   NaN
# 42   NaN
# 43   NaN
# 44   NaN
# 45   NaN
# 46   NaN
# 47   NaN
# 48   NaN
# 49   NaN
# 50   NaN
# Name: Name of City, dtype: float64
